# %%
from bronze_layer import BronzeLayer
from silver_layer import SilverLayer
from authenticate import authenticate_garmin
import datetime as dt

# %%
GARMIN_USERNAME='uzer-mughal@hotmail.co.uk'
GARMIN_PASSWORD='Alhamdolila123!'
start_date = dt.date(2025, 5, 1)
end_date = dt.date(2025, 5, 30)


garmin = authenticate_garmin(GARMIN_USERNAME, GARMIN_PASSWORD)
# Out:
# Successfully logged in to Garmin Connect.

# %%
garmin_bronze = BronzeLayer(garmin, start_date, end_date)

# %%
garmin_bronze_df = garmin_bronze.run()
# Out:
# [Bronze] Retrieved 28 activities.
# [Bronze] Created DataFrame with shape: (28, 103)

# %%
garmin_bronze_df
# Out:
#      activityId                            activityName       startTimeLocal  \
# 0   19282789832                                Strength  2025-05-30 19:36:56
# 1   19273795293  Hammersmith and Fulham Soccer/Football  2025-05-29 19:30:42
# 2   19253569698                                Strength  2025-05-27 20:18:20
# 3   19240173006                      Mole Valley Hiking  2025-05-26 10:39:42
# 4   19234727815    Kingston upon Thames Soccer/Football  2025-05-25 21:09:23
# 5   19223851328                                Strength  2025-05-24 18:54:43
# 6   19214896461              Wandsworth Soccer/Football  2025-05-23 20:40:14
# 7   19205903882                                Strength  2025-05-22 19:59:03
# 8   19195595346                      Lambeth - Recovery  2025-05-21 19:22:45
# 9   19185707891                                Strength  2025-05-20 19:02:51
# 10  19174991519              Wandsworth Soccer/Football  2025-05-19 18:57:35
# ...

# %%
silver_layer = SilverLayer(garmin_bronze_df)
silver_layer_df = silver_layer.run()
# Out:
# [Silver] Created silver DataFrame with shape: (28, 25)

# %%
silver_layer_df.head()
# Out:
#     activityId                            activityName  aerobicTrainingEffect  \
# 0  19282789832                                Strength                    0.3
# 1  19273795293  Hammersmith and Fulham Soccer/Football                    3.2
# 2  19253569698                                Strength                    0.3
# 3  19240173006                      Mole Valley Hiking                    1.3
# 4  19234727815    Kingston upon Thames Soccer/Football                    1.2
#
#   aerobicTrainingEffectMessage  anaerobicTrainingEffect  averageHR  \
# 0        NO_AEROBIC_BENEFIT_18                      0.0       95.0
# 1     IMPROVING_AEROBIC_BASE_8                      3.1      145.0
# 2        NO_AEROBIC_BENEFIT_18                      0.0       96.0
# 3      MINOR_AEROBIC_BENEFIT_0                      0.6       93.0
# 4                   RECOVERY_5                      1.3      102.0
#
#    averageRunningCadenceInStepsPerMinute  averageSpeed  beginTimestamp  \
# ...

# %%
from db_models import DBModels

# %%
db_models = DBModels(db_path='garmin_data.db')

# %%
dir(db_models)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'conn',
#  'cursor',
#  'db_path',
#  'map_dtype_to_sqlite',
#  'upload_dataframe_to_sqlite']

# %%
db_models = DBModels(db_path='garmin_data.db')
_ = db_models.upload_dataframe_to_sqlite('activities_data', silver_layer_df)
print(result)
# Out:
# TEXT
